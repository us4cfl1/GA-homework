# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# To explore from the given data whether ACT or SAT is more popular in the US and how to improve the participation rate of the test that is "less" popular.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#df_act_2017 = pd.read_csv("http://localhost:8888/edit/Desktop/Github/classes/classes/projects1234/project_1/data/act_2017.csv")
#df_sat_2017 = pd.read_csv("http://localhost:8888/edit/Desktop/Github/classes/classes/projects1234/project_1/data/sat_2017.csv")

# %%
df_act_2017 = pd.read_csv("../data/act_2017.csv")
df_sat_2017 = pd.read_csv("../data/sat_2017.csv")

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
df_act_2017.tail(10)
# Out:
#             State Participation  English  Math  Reading  Science  Composite
# 42   South Dakota           80%     20.7  21.5     22.3     22.0       21.8
# 43      Tennessee          100%     19.5  19.2     20.1     19.9       19.8
# 44          Texas           45%     19.5  20.7     21.1     20.9       20.7
# 45           Utah          100%     19.5  19.9     20.8     20.6       20.3
# 46        Vermont           29%     23.3  23.1     24.4     23.2       23.6
# 47       Virginia           29%     23.5  23.3     24.6     23.5       23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0       21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5       20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9       20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6       20.2

# %%
df_sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: For ACT 2017, it was observed that the states which had higher than the national average scores  generally had a lower participation rates compared to other states which had lower national average scores. This could mean that (i) ACT is not made compulsory in these states and (ii) the students taking the ACT were mainly high-flyers who wished to use their ACT scores to get into better colleges.
#
# For SAT 2017, it was quickly observed that only some states had declared the SAT compulsory(100% participation rate). Similar to the ACT, states which scored better composite scores tend to have lower participation rates.
#
# If we were to compare the paricipation rates of SAT and ACT in different states, it was observed generally that states with high SAT participation tend to have much lower ACT participation and the same is true vice versa.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Generally, the 2 datasets looked complete.  However, the ACT_2017 dataset had the national data, while SAT_2017 did not have.

# %%
df_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 2.9+ KB

# %%
df_sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: It was observed that the numerical  data for participation rates for both ACT and SAT existed in "object" datatype. Perhaps it would be better to standardise all numerical data to float datatypes. The "composite" data for ACT_2017 also existed as "object" datatype.

# %%
# Minimum possible value for ACT 2017
df_act_2017.min()
# Out:
# State            Alabama
# Participation        60%
# English             16.3
# Math                  18
# Reading             18.1
# Science              2.3
# Composite           17.8
# dtype: object

# %%
# Maximum possible value for ACT 2017
df_act_2017.max()
# Out:
# State            Wyoming
# Participation        98%
# English             25.5
# Math                25.3
# Reading               26
# Science             24.9
# Composite           25.5
# dtype: object

# %%
# Minimum possible value for SAT 2017
df_sat_2017.min()
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
# dtype: object

# %%
# Maximum possible value for SAT 2017
df_sat_2017.max()
# Out:
# State                                 Wyoming
# Participation                             96%
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
# dtype: object

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# Remove the "%" character and assign participation column from an "object" to a "float" under ACT_2017

df_act_2017['Participation'] = df_act_2017['Participation'].str.replace('%',"").astype('float')
df_act_2017.head(3)
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           60.0     20.3  20.7     21.4     21.0       21.0
# 1   Alabama          100.0     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           65.0     18.7  19.8     20.4     19.9       19.8

# %%
# Remove the "%" character and assign participation column from an "object" to a "float" under SAT_2017

df_sat_2017['Participation'] = df_sat_2017['Participation'].str.replace('%',"").astype('float')
df_sat_2017.head(3)
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            5.0                                 593   572   1165
# 1   Alaska           38.0                                 547   533   1080
# 2  Arizona           30.0                                 563   553   1116

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code

df_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
df_sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: The datatype of "Composite" column in ACT_2017 still remained as an object category even though I had tried to assign them as float since they contained numeric values.
#
# Also, the participation rates were not displayed as an appropriate numeric type.  They should be divided by 100.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
def convert(num):
    
    new_rate = num / 100
    return(new_rate)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
df_act_2017['Participation'] = df_act_2017['Participation'].apply(convert)
df_act_2017.head(5)
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %%
df_sat_2017['Participation'] = df_sat_2017['Participation'].apply(convert)
df_sat_2017.head(5)
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Data types of ACT_2017

df_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
# Data types of SAT_2017

df_sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#Renaming the columns of ACT_2017

df_act_2017 = df_act_2017.rename(columns = {'Participation' : 'ACT_participation', 'English' : 'ACT_english', 'Math' : 'ACT_math', 'Reading' : "ACT_reading", "Science" : "ACT_science", "Composite": "ACT_composite"})
df_act_2017.head()
# Out:
#       State  ACT_participation  ACT_english  ACT_math  ACT_reading  \
# 0  National               0.60         20.3      20.7         21.4
# 1   Alabama               1.00         18.9      18.4         19.7
# 2    Alaska               0.65         18.7      19.8         20.4
# 3   Arizona               0.62         18.6      19.8         20.1
# 4  Arkansas               1.00         18.9      19.0         19.7
#
#    ACT_science  ACT_composite
# 0         21.0           21.0
# 1         19.4           19.2
# 2         19.9           19.8
# 3         19.8           19.7
# 4         19.5           19.4

# %%
#Renaming the columns of SAT_2017

df_sat_2017 = df_sat_2017.rename(columns = {'Participation' : 'SAT_participation', 'Evidence-Based Reading and Writing':'SAT_EBRW', 'Writing': 'SAT_writing', 'Math':'SAT_math', 'Total':'SAT_total'})
df_sat_2017.head()
# Out:
#         State  SAT_participation  SAT_EBRW  SAT_math  SAT_total
# 0     Alabama               0.05       593       572       1165
# 1      Alaska               0.38       547       533       1080
# 2     Arizona               0.30       563       553       1116
# 3    Arkansas               0.03       614       594       1208
# 4  California               0.53       531       524       1055

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|object|ACT/SAT|American state where ACT or SAT is taken|
# |Participation|float|ACT/SAT|Denotes the participation rates of the students in the particular state taking ACT or SAT|
# |ACT_english|float|ACT|Average scores of all the students taking the English subject in the particular state|
# |ACT_math|float|ACT|Average scores of all the students taking the Math subject in the particular state|
# |ACT_reading|float|ACT|Average scores of all the students taking Reading in the particular state|
# |ACT_science|float|ACT|Average scores of all the students taking Science in the particular state|
# |Composite|object|ACT|Average scaled scores for all the 4 ACT subjects taken|
# |SAT_Math|float|SAT|Average scores of all the students taking SAT Science in the particular state|
# |SAT_EBRW|float|SAT|Average scores of all the students taking Evidence Based Reading & Writing in the particular state|
# |SAT_total|float|SAT|Total average scores of SAT_math and SAT_EBRW|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# To remove the "National" row in our ACT_2017 data

df_act_2017 = df_act_2017.drop([0])
df_act_2017.head(5)
# Out:
#         State  ACT_participation  ACT_english  ACT_math  ACT_reading  \
# 1     Alabama               1.00         18.9      18.4         19.7
# 2      Alaska               0.65         18.7      19.8         20.4
# 3     Arizona               0.62         18.6      19.8         20.1
# 4    Arkansas               1.00         18.9      19.0         19.7
# 5  California               0.31         22.5      22.7         23.1
#
#    ACT_science  ACT_composite
# 1         19.4           19.2
# 2         19.9           19.8
# 3         19.8           19.7
# 4         19.5           19.4
# 5         22.2           22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
merge_data_2017 = pd.merge(df_act_2017, df_sat_2017, how='inner', on='State')
merge_data_2017.head()
# Out:
#         State  ACT_participation  ACT_english  ACT_math  ACT_reading  \
# 0     Alabama               1.00         18.9      18.4         19.7
# 1      Alaska               0.65         18.7      19.8         20.4
# 2     Arizona               0.62         18.6      19.8         20.1
# 3    Arkansas               1.00         18.9      19.0         19.7
# 4  California               0.31         22.5      22.7         23.1
#
#    ACT_science  ACT_composite  SAT_participation  SAT_EBRW  SAT_math  \
# 0         19.4           19.2               0.05       593       572
# 1         19.9           19.8               0.38       547       533
# 2         19.8           19.7               0.30       563       553
# 3         19.5           19.4               0.03       614       594
# 4         22.2           22.8               0.53       531       524
#
#    SAT_total
# 0       1165
# 1       1080
# 2       1116
# 3       1208
# 4       1055

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
merge_data_2017.to_csv("../data/merge_data_2017.csv")

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# Load ACT_2018 into a dataframe

df_act_2018 = pd.read_csv("../data/ACT_2018.csv")
df_act_2018.head()

#Convert the participation rate using the convert function above.

df_act_2018['Participation'] = df_act_2018['Participation'].apply(convert)

# Rename the header to reflect that it is ACT results

df_act_2018 = df_act_2018.rename(columns = {'Participation' : 'ACT18_participation', 'English' : 'ACT18_english', 'Math' : 'ACT18_math', 'Reading' : "ACT18_reading", "Science" : "ACT18_science", "Composite": "ACT18_composite"})
df_act_2018.info()
df_act_2018.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
# State                  51 non-null object
# ACT18_participation    51 non-null float64
# ACT18_english          51 non-null float64
# ACT18_math             51 non-null float64
# ACT18_reading          51 non-null float64
# ACT18_science          51 non-null float64
# ACT18_composite        51 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB
#         State  ACT18_participation  ACT18_english  ACT18_math  ACT18_reading  \
# 0     Alabama                 1.00           18.9        18.3           19.6
# 1      Alaska                 0.33           19.8        20.6           21.6
# 2     Arizona                 0.66           18.2        19.4           19.5
# 3    Arkansas                 1.00           19.1        18.9           19.7
# 4  California                 0.27           22.5        22.5           23.0
#
#    ACT18_science  ACT18_composite
# ...

# %%
# Load SAT_2018 into a pandas dataframe

df_sat_2018 = pd.read_csv("../data/SAT_2018.csv")
df_sat_2018.head()

# Drop the % sign under Particiation rate and convert it into an int64. Apply the convert function as well to convert it from %
# to integer

df_sat_2018['Participation'] = df_sat_2018['Participation'].str.replace('%',"").astype('int64') # can try to use lambda
df_sat_2018['Participation'] = df_sat_2018['Participation'].apply(convert)

#Rename to reflect that these are the results of SAT 2018.
df_sat_2018 = df_sat_2018.rename(columns = {'Participation' : 'SAT18_participation', 'Evidence-Based Reading and Writing':'SAT18_EBRW', 'Writing': 'SAT18_writing', 'Math':'SAT18_math', 'Total':'SAT18_total'})

df_sat_2018.info()
df_sat_2018.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                  51 non-null object
# SAT18_participation    51 non-null float64
# SAT18_EBRW             51 non-null int64
# SAT18_math             51 non-null int64
# SAT18_total            51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
#         State  SAT18_participation  SAT18_EBRW  SAT18_math  SAT18_total
# 0     Alabama                 0.06         595         571         1166
# 1      Alaska                 0.43         562         544         1106
# 2     Arizona                 0.29         577         572         1149
# 3    Arkansas                 0.05         592         576         1169
# 4  California                 0.60         540         536         1076

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# Merge df of both SAT 2018 and ACT 2018 together

merge_data_2018 = pd.merge(df_act_2018, df_sat_2018, how='inner', on='State')
merge_data_2018.head()

# Merge dfs of both merged data of 2017 and 2018

final = pd.merge(merge_data_2017, merge_data_2018, how = "inner", on = 'State')
final.head()
final.to_csv("../data/final.csv")

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final_info = final.describe()
final_info.transpose()
# Out:
#                      count         mean        std     min       25%      50%  \
# ACT_participation     51.0     0.652549   0.321408    0.08     0.310     0.69
# ACT_english           51.0    20.931373   2.353677   16.30    19.000    20.70
# ACT_math              51.0    21.182353   1.981989   18.00    19.400    20.90
# ACT_reading           51.0    22.013725   2.067271   18.10    20.450    21.80
# ACT_science           51.0    21.041176   3.182463    2.30    19.900    21.30
# ACT_composite         51.0    21.519608   2.020695   17.80    19.800    21.40
# SAT_participation     51.0     0.398039   0.352766    0.02     0.040     0.38
# SAT_EBRW              51.0   569.117647  45.666901  482.00   533.500   559.00
# SAT_math              51.0   547.627451  84.909119   52.00   522.000   548.00
# SAT_total             51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# ACT18_participation   51.0     0.616471   0.340810    0.07     0.285     0.66
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
final.head()
# Out:
#         State  ACT_participation  ACT_english  ACT_math  ACT_reading  \
# 0     Alabama               1.00         18.9      18.4         19.7
# 1      Alaska               0.65         18.7      19.8         20.4
# 2     Arizona               0.62         18.6      19.8         20.1
# 3    Arkansas               1.00         18.9      19.0         19.7
# 4  California               0.31         22.5      22.7         23.1
#
#    ACT_science  ACT_composite  SAT_participation  SAT_EBRW  SAT_math  ...  \
# 0         19.4           19.2               0.05       593       572  ...
# 1         19.9           19.8               0.38       547       533  ...
# 2         19.8           19.7               0.30       563       553  ...
# 3         19.5           19.4               0.03       614       594  ...
# 4         22.2           22.8               0.53       531       524  ...
#
#    ACT18_participation  ACT18_english  ACT18_math  ACT18_reading  \
# ...

# %%
def standard_deviation(col): 
    
    mean_value = np.mean(col) 
    inside_root = sum([(i-mean_value)**2 for i in col]) / len(col)
    return np.sqrt(inside_root)

# %%
#Test out the SD on a column under final df.

standard_deviation(final['ACT_participation'])
# Out:
# 0.3182417575123181

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {k:standard_deviation(final[k]) for k in final.columns[1:]}

# %%
sd
# Out:
# {'ACT_participation': 0.3182417575123181,
#  'ACT_english': 2.3304876369363363,
#  'ACT_math': 1.9624620273436781,
#  'ACT_reading': 2.0469029314842646,
#  'ACT_science': 3.151107895464408,
#  'ACT_composite': 2.000786081581989,
#  'SAT_participation': 0.3492907076664507,
#  'SAT_EBRW': 45.21697020437866,
#  'SAT_math': 84.07255521608297,
#  'SAT_total': 91.58351056778743,
#  'ACT18_participation': 0.33745194881997503,
#  'ACT18_english': 2.4222536143202795,
#  'ACT18_math': 2.015707255555717,
#  'ACT18_reading': 2.145891884510421,
#  'ACT18_science': 1.8516885484833543,
#  'ACT18_composite': 2.0855261815801147,
#  'SAT18_participation': 0.3763965409204987,
#  'SAT18_EBRW': 44.87118561762388,
#  'SAT18_math': 48.40589946919447,
#  'SAT18_total': 92.94224786343668}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
final.describe().T

# The manually calculated standard deviation is somewhat close to the value using the describe method on the final dataframe.
# Out:
#                      count         mean        std     min       25%      50%  \
# ACT_participation     51.0     0.652549   0.321408    0.08     0.310     0.69
# ACT_english           51.0    20.931373   2.353677   16.30    19.000    20.70
# ACT_math              51.0    21.182353   1.981989   18.00    19.400    20.90
# ACT_reading           51.0    22.013725   2.067271   18.10    20.450    21.80
# ACT_science           51.0    21.041176   3.182463    2.30    19.900    21.30
# ACT_composite         51.0    21.519608   2.020695   17.80    19.800    21.40
# SAT_participation     51.0     0.398039   0.352766    0.02     0.040     0.38
# SAT_EBRW              51.0   569.117647  45.666901  482.00   533.500   559.00
# SAT_math              51.0   547.627451  84.909119   52.00   522.000   548.00
# SAT_total             51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# ACT18_participation   51.0     0.616471   0.340810    0.07     0.285     0.66
# ...

# %%
# Numpy's standard deviation

final.std()

# Numpy's standard deviation calculation is the same as the panda's df.
# Out:
# ACT_participation       0.321408
# ACT_english             2.353677
# ACT_math                1.981989
# ACT_reading             2.067271
# ACT_science             3.182463
# ACT_composite           2.020695
# SAT_participation       0.352766
# SAT_EBRW               45.666901
# SAT_math               84.909119
# SAT_total              92.494812
# ACT18_participation     0.340810
# ACT18_english           2.446356
# ACT18_math              2.035765
# ACT18_reading           2.167245
# ACT18_science           1.870114
# ACT18_composite         2.106278
# SAT18_participation     0.380142
# SAT18_EBRW             45.317676
# SAT18_math             48.887562
# SAT18_total            93.867069
# dtype: float64

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# sorted 2017 ACT data

df_act_2017.sort_values('ACT_participation').head() # Maine has the lowest participation rate for ACT 2017.

df_act_2017.sort_values(by = ['ACT_participation'], ascending = False).head(20) # It can be seen that 17 US states have the
# highest participation rate of 1.
# Out:
#              State  ACT_participation  ACT_english  ACT_math  ACT_reading  \
# 1          Alabama               1.00         18.9      18.4         19.7
# 18        Kentucky               1.00         19.6      19.4         20.5
# 50       Wisconsin               1.00         19.7      20.4         20.6
# 45            Utah               1.00         19.5      19.9         20.8
# 43       Tennessee               1.00         19.5      19.2         20.1
# 41  South Carolina               1.00         17.5      18.6         19.1
# 37        Oklahoma               1.00         18.5      18.8         20.1
# 34  North Carolina               1.00         17.8      19.3         19.6
# 29          Nevada               1.00         16.3      18.0         18.1
# 27         Montana               1.00         19.0      20.2         21.0
# 25     Mississippi               1.00         18.2      18.1         18.8
# 24       Minnesota               1.00         20.4      21.5         21.8
# ...

# %%
# sorted 2017 SAT data

df_sat_2017.sort_values('SAT_participation').head() # North Dakota, Mississippi and Lowa have the lowest participation rate for SAT 2017.

df_sat_2017.sort_values(by = ['SAT_participation'], ascending = False).head(10) # It can be seen that 4 US states have the
# highest participation rate of 1.
# Out:
#                    State  SAT_participation  SAT_EBRW  SAT_math  SAT_total
# 8   District of Columbia               1.00       482       468        950
# 22              Michigan               1.00       509       495       1005
# 6            Connecticut               1.00       530       512       1041
# 7               Delaware               1.00       503       492        996
# 29         New Hampshire               0.96       532       520       1052
# 19                 Maine               0.95       513       499       1012
# 12                 Idaho               0.93       513       493       1005
# 9                Florida               0.83       520       497       1017
# 21         Massachusetts               0.76       555       551       1107
# 39          Rhode Island               0.71       539       524       1062

# %%
# sorted 2018 ACT data

df_act_2018.sort_values('ACT18_participation').head() # Again, Maine has the lowest participation rate for ACT 2018.
# Out:
#             State  ACT18_participation  ACT18_english  ACT18_math  \
# 19          Maine                 0.07           23.8        23.6
# 39   Rhode Island                 0.15           24.4        23.6
# 29  New Hampshire                 0.16           25.1        24.7
# 7        Delaware                 0.17           23.7        23.1
# 38   Pennsylvania                 0.20           23.3        23.2
#
#     ACT18_reading  ACT18_science  ACT18_composite
# 19           24.7           23.4             24.0
# 39           25.0           23.5             24.2
# 29           25.6           24.4             25.1
# 7            24.5           23.4             23.2
# 38           24.0           23.1             23.5

# %%
# sorted 2018 SAT data

df_sat_2018.sort_values('SAT18_participation', ascending = False).head(10) # 5 US states have the highest participation rate for
#SAT 2018.
# Out:
#             State  SAT18_participation  SAT18_EBRW  SAT18_math  SAT18_total
# 5        Colorado                 1.00         519         506         1025
# 6     Connecticut                 1.00         535         519         1053
# 7        Delaware                 1.00         505         492          998
# 22       Michigan                 1.00         511         499         1011
# 12          Idaho                 1.00         508         493         1001
# 19          Maine                 0.99         512         501         1013
# 13       Illinois                 0.99         513         506         1019
# 39   Rhode Island                 0.97         513         505         1018
# 9         Florida                 0.97         522         493         1014
# 29  New Hampshire                 0.96         535         528         1063

# %%
# Which states have the highest and lowest mean total/composite scores for SAT 2017


df_sat_2017.sort_values('SAT_total').head() #DIstrict of Columbia has the lowest SAT total scores for 2017

df_sat_2017.sort_values('SAT_total', ascending = False).head()  # Minnesota has the highest SAT total scores for 2017.
# Out:
#         State  SAT_participation  SAT_EBRW  SAT_math  SAT_total
# 23  Minnesota               0.03       644       651       1295
# 49  Wisconsin               0.03       642       649       1291
# 15       Iowa               0.02       641       635       1275
# 25   Missouri               0.03       640       631       1271
# 16     Kansas               0.04       632       628       1260

# %%
# Which states have the highest and lowest mean total/composite scores for SAT 2018

df_sat_2018.sort_values('SAT18_total').head()  # District of Columbia has the lowest SAT scoresfor 2018 again. 

df_sat_2018.sort_values('SAT18_total', ascending = False).head() # Minnesota hs the highest SAT scores for 2018 again.
# Out:
#            State  SAT18_participation  SAT18_EBRW  SAT18_math  SAT18_total
# 23     Minnesota                 0.04         643         655         1298
# 49     Wisconsin                 0.03         641         653         1294
# 34  North Dakota                 0.02         640         643         1283
# 15          Iowa                 0.03         634         631         1265
# 16        Kansas                 0.04         633         631         1264

# %%
# Which states have the highest and lowest mean total/composite scores for ACT 2017

df_act_2017.sort_values('ACT_composite') # Nevada and New Hampshire has the lowest and highest mean composite scores for ACT 2017
# Out:
#                    State  ACT_participation  ACT_english  ACT_math  \
# 29                Nevada               1.00         16.3      18.0
# 25           Mississippi               1.00         18.2      18.1
# 41        South Carolina               1.00         17.5      18.6
# 12                Hawaii               0.90         17.8      19.2
# 34        North Carolina               1.00         17.8      19.3
# 1                Alabama               1.00         18.9      18.4
# 4               Arkansas               1.00         18.9      19.0
# 37              Oklahoma               1.00         18.5      18.8
# 19             Louisiana               1.00         19.4      18.8
# 3                Arizona               0.62         18.6      19.8
# 32            New Mexico               0.66         18.6      19.4
# 2                 Alaska               0.65         18.7      19.8
# 43             Tennessee               1.00         19.5      19.2
# ...

# %%
# Which states have the highest and lowest mean total/composite scores for ACT 2018

df_act_2018.sort_values('ACT18_composite') # Nevada has the lowest and Connecticut has the highest mean composite scores for ACT 2018
# Out:
#                    State  ACT18_participation  ACT18_english  ACT18_math  \
# 28                Nevada                 1.00           16.6        17.8
# 40        South Carolina                 1.00           17.3        18.2
# 24           Mississippi                 1.00           18.2        18.1
# 11                Hawaii                 0.89           18.2        19.0
# 0                Alabama                 1.00           18.9        18.3
# 33        North Carolina                 1.00           18.0        19.3
# 2                Arizona                 0.66           18.2        19.4
# 18             Louisiana                 1.00           19.0        18.5
# 36              Oklahoma                 1.00           18.4        18.8
# 3               Arkansas                 1.00           19.1        18.9
# 31            New Mexico                 0.67           18.3        19.1
# 42             Tennessee                 1.00           19.4        19.1
# ...

# %%
# Do any states with 100% participation on a given test have a rate change year-to-year?
# Ans:  Yes for both SAT and ACT.  The differences are found by doing a sort_value

#df_act_2017.sort_values(by = ['ACT_participation'], ascending = False).head(20)
#df_act_2018.sort_values(by = ['ACT18_participation'], ascending = False).head(20)

#df_sat_2017.sort_values(by = ['SAT_participation'], ascending = False).head(10)
#df_sat_2018.sort_values(by = ['SAT18_participation'], ascending = False).head(10)

# %%
# Do any states show have >50% participation on both tests either year? Yes, 28 states
#Apply masking on ACT 2017 and 2018

mask_2017 = final['ACT_participation'] > 0.5
mask_2018 = final['ACT18_participation'] > 0.5
final[mask_2018]
# Out:
#              State  ACT_participation  ACT_english  ACT_math  ACT_reading  \
# 0          Alabama               1.00         18.9      18.4         19.7
# 2          Arizona               0.62         18.6      19.8         20.1
# 3         Arkansas               1.00         18.9      19.0         19.7
# 9          Florida               0.73         19.0      19.4         21.0
# 10         Georgia               0.55         21.0      20.9         22.0
# 11          Hawaii               0.90         17.8      19.2         19.2
# 15            Iowa               0.67         21.2      21.3         22.6
# 16          Kansas               0.73         21.1      21.3         22.3
# 17        Kentucky               1.00         19.6      19.4         20.5
# 18       Louisiana               1.00         19.4      18.8         19.8
# 23       Minnesota               1.00         20.4      21.5         21.8
# 24     Mississippi               1.00         18.2      18.1         18.8
# ...

# %%
#Apply masking on SAT 2017 and 2018

SAT_mask_2017 = final['SAT_participation'] > 0.5
SAT_mask_2018 = final['SAT18_participation'] > 0.5

final[SAT_mask_2017]
final[SAT_mask_2018]
# Out:
#                    State  ACT_participation  ACT_english  ACT_math  \
# 4             California               0.31         22.5      22.7
# 5               Colorado               1.00         20.1      20.3
# 6            Connecticut               0.31         25.5      24.6
# 7               Delaware               0.18         24.1      23.4
# 8   District of Columbia               0.32         24.4      23.5
# 9                Florida               0.73         19.0      19.4
# 10               Georgia               0.55         21.0      20.9
# 11                Hawaii               0.90         17.8      19.2
# 12                 Idaho               0.38         21.9      21.8
# 13              Illinois               0.93         21.0      21.2
# 14               Indiana               0.35         22.0      22.4
# 19                 Maine               0.08         24.2      24.0
# 20              Maryland               0.28         23.3      23.1
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


plt.figure(figsize=(15,15))
plt.title('Heatmap to show correlations')
sns.heatmap(final.corr(), annot=True)

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Histogram of the participation rates for SAT & ACT 2017

def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2) 
    ax = ax.ravel() 
    for i, column in enumerate(list_of_columns):
        ax[i].hist(dataframe[column]) 
        plt.suptitle(list_of_titles)
        plt.xlabel(list_of_xlabels)

   
subplot_histograms(final, ['ACT_participation', 'SAT_participation'],'Histogram of ACT & SAT participation rates 2017', 'ACT (left) and SAT (right) participation rates')


# It can be seen that there are far more states which have a 100% participation rates for ACT compared to SAT. In addition, there are
# more states with lower particiption rates compared to ACT.

# %%
#  Histogram of the participation rates for SAT & ACT 2018

subplot_histograms(final, ['ACT18_participation', 'SAT18_participation'],'Histogram of ACT & SAT participation rates 2018', 'ACT (left) and SAT (right) participation rates')

# The trend is similar to 2017, with ACT having more states with 100% Participation rates compared to SAT.

# %%
# Math scores for SAT & ACT 2017

subplot_histograms(final, ['ACT_math', 'SAT_math'],'Histogram of ACT & SAT Math 2017', 'ACT (left) and SAT (right) math scores')

# The SAT 2017 Math scores seems skewed compared to 2018 SAT maths scores, meaning alot of states taking the SAT did very well.

# %%
# Math scores for SAT & ACT 2018

subplot_histograms(final, ['ACT18_math', 'SAT18_math'],'Histogram of ACT & SAT Math 2018', 'ACT (left) and SAT (right) math scores')

# The distribution graphs for SAT and ACT 2018 math scores were

# %%
 # Reading/verbal scores for SAT & ACT 2017
    
subplot_histograms(final, ['ACT_reading', 'SAT_EBRW'],'Histogram of ACT & SAT reading / verbal scores 2017', 'ACT (left) and SAT (right) reading/verbal scores')

# %%
# Reading/verbal scores for SAT & ACT 2018

subplot_histograms(final, ['ACT18_reading', 'SAT18_EBRW'],'Histogram of ACT & SAT reading / verbal scores 2018', 'ACT (left) and SAT (right) reading/verbal scores')

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Scatter plots for SAT vs. ACT math scores for 2017

plt.figure(figsize=(6,6))
sns.lmplot(x = 'SAT_math', y ='ACT_math', data = final)
plt.title('Scatter plot of SAT & ACT math 2017')

# There seems to be no correlation between the math scores for SAT and ACT in 2017 as there is no obvious trend of the datapoints.
# There is also an outlier datapoint.

# %%
# Scatter plot for SAT vs. ACT verbal/reading scores for 2017


plt.figure(figsize=(6,6))
sns.lmplot(x = 'SAT_EBRW', y ='ACT_reading', data = final)
plt.title('Scatter plot of SAT & ACT verbal/reading 2017')

# It is weakly or even not correlated with each other.

# %%
# Total scores for SAT 2017 vs. 2018

plt.figure(figsize=(6,6))
sns.lmplot(x = 'SAT_total', y ='SAT18_total', data = final)
plt.title('Scatter plot of SAT 2017 vs SAT 2018')

# It is clearly positively correlated to each other.  The few outliers are the states where their SAT results differ 
# quite alot from the previous year

# %%
# Composite scores for ACT 2017 vs. 2018

plt.figure(figsize=(6,6))
sns.lmplot(x = 'ACT_composite', y ='ACT18_composite', data = final)
plt.title('Scatter plot of ACT 2017 vs ACT 2018')

# It is clearly positively correlated to each other.  The few outliers are the states where their ACT results differ 
# quite alot from the previous year

# %%
# SAT vs. ACT total/composite scores for 2017

plt.figure(figsize=(6,6))
sns.lmplot(x = 'SAT_total', y ='ACT_composite', data = final)
plt.title('Scatter plot of SAT vs ACT total/composite scores 2017')

#No correlation to each other at all.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Merge ACT data for 2017 and 2018
combined_act = pd.merge(df_act_2017, df_act_2018, how='inner', on='State')
combined_act = combined_act.drop(['ACT_participation', 'ACT18_participation'], axis=1)
combined_act.head()

#Plot box plot for ACT data of 2017 and 2018 minus the participation rate as they are not at the same relative scale as the rest

plt.figure(figsize=(15,8))
sns.boxplot(data = combined_act)

# %%
# Merge SAT data for 2017 and 2018
combined_sat = pd.merge(df_sat_2017, df_sat_2018, how='inner', on='State')
combined_sat = combined_sat.drop(['SAT_participation', 'SAT18_participation'], axis=1)
combined_sat.head()

#Plot box plot for SAT data of 2017 and 2018 minus the participation rate as they are not at the same relative scale as the rest

plt.figure(figsize=(15,8))
sns.boxplot(data = combined_sat)

# %%
participation_boxplots = [df_act_2017['ACT_participation'], df_act_2018['ACT18_participation'], df_sat_2017['SAT_participation'], df_sat_2018['SAT18_participation']]
plt.figure(figsize=(10,8))
plt.xlabel('Participation Rate')
sns.boxplot(data = participation_boxplots)

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# From the histogram above on participation rates of ACT and SAT, it can be seem from the charts that the participation rates for both tests differ quite a bit.  I want to deploy the numpy corrcoef to find out its correlation coefficient and to plot the scatter plot to double check.

# %%
np.corrcoef(final['ACT_participation'],final['SAT_participation']) ##Check the correlation coefficient between
# ACT and SAT participation rates

# Although it is not perfectly -1, it is quite strongly negatively correlated (-0.84)

# %%
np.corrcoef(final['ACT18_participation'],final['SAT18_participation'])

# %%
plt.figure(figsize=(6,6))
sns.lmplot(x = 'ACT_participation', y ='SAT_participation', data = final)
plt.title('Scatter plot of ACT and SAT participation rates for 2017')
# Out:
# Text(0.5, 1.0, 'Scatter plot of ACT and SAT participation rates for 2017')

# %%
plt.figure(figsize=(6,6))
sns.lmplot(x = 'ACT18_participation', y ='SAT18_participation', data = final)
plt.title('Scatter plot of ACT and SAT participation rates for 2018')

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
#
# a) The mean and median of SAT 2017 participation rate is 0.398 and 0.38 respectively. This should mean that the distribtion is normally distributed.  However, the histogram for SAT population shows a positively skewed graph. The standard deviation of the distribution is 0.35. Considering participation is measured between 0 and 1, the spread of the distribution is quite large.  As for SAT 2018 participation rate, the mean and median are 0.46 and 0.52 respectively. By right, it should be negatively skewed, but the histogram shows a positively skewed graph instead.
#
# b) For the ACT 2017 participation, the mean and median is 0.652 and 0.69 respectively.  Based on this figure, it should indicate a slightly left skewed distribution. This is also supported by the histogram for ACT plotted earlier. The standard deviation of the distribution is 0.32. Considering participation is measured between 0 and 1, the spread of the distribution is also quite large.  For ACT 2018 participation rate, the mean and median are 0.62 and 0.66 respectively. This should mean that the distribution is normally distributed.  However, the histogram shows a negatively-skewed graph instead.
#
# c) For SAT 2017 Math score distribution, the mean and median are relatively similar at 547.6 and 548 respectively. By right, it should be normally distributed. However, based on the histogram , it is very negatively skewed. The reason could be due to the outlier. A small SD of 84.9 shows that the data are clustered closely around the mean (more reliable). For SAT 2018 Math scores, the mean and median are 557.25 and 547 respectively. The histogram also supports a slight positively skewed graph.
#
# d) For ACT 2017 Math Score, the mean and median are relatively close at 21.18 and 20.9 respectively.  This should show that the distribution is normally distributed because the two values are almost identical. The historgram may not seem to show that it is normally distributed, so we need to look at standard deviation. It is 1.98 for this distribution and it shows that more values are closer to the mean. As for ACT 2018 maths scores, the situation is almost like of ACT 2017, with a slightly more SD of 2.03.
#
# e) For the ACT English scores of 2017 and 2018, based on the mean and median, it shows that the figures are very close to one another (Mean(20.9), Median(20.7) for 2017 and Mean(20.9), median(20.2) for 2018).  This would mean that the distribution should be normally distributed with SDs of 2.35 and 2.44 respectively.
#
# f) For the SAT 2017 EBRW, the mean and median are 569.1 and 559 respectively while the mean and median for SAT 2018 EBRW are 567.3 and 552 respectively. With the medians smaller than the means, it should be a slight positively-skewed graph when plot.  The spread is at about 45 which means that more datas are closer to the mean and hence a more tightly packed distribution.
#
# g)For the ACT 2017 reading Score distribution, the mean and median are 22.01 and 21.8 respectively. Mean and median for 2018 are at 22.01 and 21.6.  As the medians are slightly less than means, we should expect a slight positive skewed histogram. The spread of the distribution, according to a standard deviation value of 2.06 and 2.16, should reveal a more tightly packed distribution and that more values are close to the mean.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No. From the histograms plotted, the disturbition charts of the raw data are not normally distributed.  They are mostly skewed either to the left or right.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# The assumption that the data we sample from Math, reading and participation rates are normally distributed are all not true.  None of the histograms plotted resembles a normal distribution curve. Therefore, we should repeatedly take independent random samples of size n from the population, then when n is large, the distribution of the sample means will approach a normal distribution eventually.
#
# Once we have obtained a normally distributed result, we can then make statistical inferences (hypothesis testing etc) about data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:It does not make sense to conduct statistical inference given these data because participation rates are already biased. Some states focus on SAT while others on ACT. Therefore, random sampling of the population taking the tests is not necessary as seen from the distribution charts.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:# It would not be appropriate to generate correlation between ACT and SAT Math scores since the scales of their scores are significantly too far apart. Normalising the data will be required before any meaningful comparison can be done on these 2 Math data scores.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# The three states are a) Delaware with low ACT participation rates of 18% and 100% participation rate for SAT, b)Mississippi with a high ACT participation rate of 100% and 20% SAT participation rate and c) Missouri, another state with high ACT participation rate of 100% and 30% SAT participation rate.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# It can be concluded that states with higher participation rates in either the SAT or ACT test have much lower scores. It shows that these states require their all their students to take part in the test and hence even the worst or not so motivated students will have to take the test, hence displaying lower average scores. On the other hand, the lowest participating states tend to send primarily their best students and have the highest scores. This certainly results in bias.
#
# Hence, we cannot rely on raw average scores because these averages are biased by participation rates. A recommendation could be to adjust or normalise a state's raw test scores and compare them to other states with similar participation rates.
#
# To make comparison more meaningful, all the states could consider making either the SAT or ACT compulsory or at least offer incentives (e.g. exam fee subsidy or waiver) to encourage more students to take the tests.
